# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of `JOIN` statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# * Write SQL queries that make use of various types of joins
# * Compare and contrast the various types of joins
# * Discuss how primary and foreign keys are used in SQL
# * Decide and perform whichever type of join is best for retrieving desired data

# %% [markdown]
# ## CRM ERD
#
# In this lab, you'll use the same customer relationship management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database `'data.sqlite'`.

# %%
# Your code here
import sqlite3
import pandas as pd
conn = sqlite3.connect("data.sqlite")

# %% [markdown]
# ## Select the names of all employees in Boston
#
# Hint: join the employees and offices tables. Select the first and last name.

# %%
# Your code here
com = """
SELECT firstname, lastname
FROM employees
JOIN offices
    ON employees.officeCode = offices.officeCode
WHERE offices.city = "Boston"
"""
pd.read_sql(com, conn)
# Out:
#   firstName   lastName
# 0     Julie   Firrelli
# 1     Steve  Patterson

# %% [markdown]
# ## Are there any offices that have zero employees?
# Hint: Combine the employees and offices tables and use a group by. Select the office code, city, and number of employees.

# %%
# Your code here
com = """
SELECT COUNT(firstname) AS "Number of employees", offices.city
FROM employees
JOIN offices
    ON employees.officeCode = offices.officeCode
GROUP BY employees.officeCode;
"""
pd.read_sql(com, conn)
# Out:
#    Number of employees           city
# 0                    6  San Francisco
# 1                    2         Boston
# 2                    2            NYC
# 3                    5          Paris
# 4                    2          Tokyo
# 5                    4         Sydney
# 6                    2         London

# %% [markdown]
# ## Write 3 questions of your own and answer them

# %%
# Answers will vary

# Example question: 
"""
How many customers are there per office?
"""

# %%
"""
Question 1
How many customers are there per office?
"""

# Your code here
com = """
SELECT COUNT(firstname) AS "Number of employees", offices.city
FROM employees
JOIN offices
    ON employees.officeCode = offices.officeCode
GROUP BY employees.officeCode;
"""
pd.read_sql(com, conn)

# %%
"""
Question 2
"""

# Your code here

# %%
"""
Question 3
"""

# Your code here

# %% [markdown]
# ## Level Up 1: Display the names of every individual product that each employee has sold
#
# Hint: You will need to use multiple `JOIN` clauses to connect all the way from employee names to product names.

# %%
# Your code here

com = """
SELECT employees.firstName, employees.lastName, COUNT(products.productName) AS "Number of product per order", products.productName, orderdetails.orderNumber
FROM employees
JOIN offices
    ON employees.officeCode = offices.officeCode,
    customers
    ON employees.employeeNumber = customers.SalesRepEmployeeNumber,
    orders
    ON customers.customerNumber = orders.customerNumber,
    orderdetails
    USING (orderNumber),
    products
    USING (productCode)   
GROUP BY orderdetails.orderNumber
LIMIT 50
"""
pd.read_sql(com, conn)
# Out:
#    firstName   lastName  Number of product per order  \
# 0      Steve  Patterson                            4
# 1      Barry      Jones                            4
# 2   Foon Yue      Tseng                            2
# 3      Barry      Jones                           16
# 4     Gerard  Hernandez                           13
# 5     Pamela   Castillo                           15
# 6     Pamela   Castillo                           18
# 7     George     Vanauf                            8
# 8       Mami      Nishi                           16
# 9     George     Vanauf                            6
# 10     Larry       Bott                           16
# 11    Leslie   Jennings                            6
# 12     Barry      Jones                            2
# 13    Leslie   Jennings                            4
# 14      Loui     Bondur                           10
# 15  Foon Yue      Tseng                            5
# 16    Pamela   Castillo                            1
# ...

# %% [markdown]
# ## Level Up 2: Display the number of products each employee has sold
#
# Alphabetize the results by employee last name.
#
# Hint: Use the `quantityOrdered` column from `orderDetails`. Also, think about how to group the data when some employees might have the same first or last name.

# %%
# Your code here

com = """
SELECT employees.firstName, employees.lastName, SUM(orderDetails.quantityOrdered)
FROM employees
JOIN offices
    ON employees.officeCode = offices.officeCode,
    customers
    ON employees.employeeNumber = customers.SalesRepEmployeeNumber,
    orders
    ON customers.customerNumber = orders.customerNumber,
    orderdetails
    USING (orderNumber),
    products
    USING (productCode)   

GROUP BY employees.lastName
ORDER BY employees.lastName
LIMIT 50
"""
pd.read_sql(com, conn)
# Out:
#   firstName   lastName  number of products
# 0     Larry       Bott                 236
# 1    Pamela   Castillo                 272
# 2    Gerard  Hernandez                 396
# 3    Leslie   Jennings                 331
# 4     Barry      Jones                 220
# 5    George     Vanauf                 211

# %% [markdown]
# ## Level Up 3: Display the names employees who have sold more than 200 different products
#
# Hint: this is different from the previous question because the quantity sold doesn't matter, only the number of different products

# %%
# Your code here

com = """
SELECT employees.firstName, employees.lastName, COUNT(products.productName) AS "number of products"
FROM employees
JOIN offices
    ON employees.officeCode = offices.officeCode,
    customers
    ON employees.employeeNumber = customers.SalesRepEmployeeNumber,
    orders
    ON customers.customerNumber = orders.customerNumber,
    orderdetails
    USING (orderNumber),
    products
    USING (productCode)   

GROUP BY employees.lastName
HAVING COUNT(products.productName) > 200
ORDER BY employees.lastName
LIMIT 50
"""
pd.read_sql(com, conn)
# Out:
#    firstName   lastName  SUM(orderDetails.quantityOrdered)
# 0       Loui     Bondur                               6186
# 1      Larry       Bott                               8205
# 2     Pamela   Castillo                               9290
# 3      Julie   Firrelli                               4227
# 4       Andy     Fixter                               6246
# 5     Martin     Gerard                               4180
# 6     Gerard  Hernandez                              14231
# 7     Leslie   Jennings                              11854
# 8      Barry      Jones                               7486
# 9      Peter      Marsh                               6632
# 10      Mami      Nishi                               4923
# 11     Steve  Patterson                               5561
# 12    Leslie   Thompson                               4056
# 13  Foon Yue      Tseng                               5016
# 14    George     Vanauf                               7423

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You practiced using join statements and leveraged your foreign keys knowledge!
